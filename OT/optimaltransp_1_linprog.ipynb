# %% [markdown]
# Optimal Transport with Linear Programming
# =========================================
#
# *Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.

# %% [markdown]
# This numerical tours details how to solve the discrete optimal transport
# problem (in the case of measures that are sums of Diracs) using linear
# programming.

# %% [markdown]
# You need to install [CVXPY](https://www.cvxpy.org/). _Warning:_ seems to not be working on Python 3.7, use rather 3.6.

# %%
# !pip install cvxpy
# Out:
# Collecting cvxpy
#   Downloading cvxpy-1.5.3-cp312-cp312-macosx_10_9_universal2.whl.metadata (8.8 kB)
# Collecting osqp>=0.6.2 (from cvxpy)
#   Downloading osqp-0.6.7.post3-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Collecting ecos>=2 (from cvxpy)
#   Downloading ecos-2.0.14.tar.gz (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clarabel>=0.5.0 (from cvxpy)
#   Downloading clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy)
#   Downloading scs-3.2.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.15 in /opt/anaconda3/lib/python3.12/site-packages (from cvxpy) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from cvxpy) (1.14.1)
# Collecting qdldl (from osqp>=0.6.2->cvxpy)
#   Downloading qdldl-0.1.7.post4-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.7 kB)
# Downloading cvxpy-1.5.3-cp312-cp312-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.0 MB/s eta 0:00:00a 0:00:01
# Downloading clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.2 MB/s eta 0:00:0000:0100:01
# Downloading osqp-0.6.7.post3-cp312-cp312-macosx_11_0_arm64.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.6/237.6 kB 13.6 MB/s eta 0:00:00
# Downloading scs-3.2.7-cp312-cp312-macosx_11_0_arm64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 13.2 MB/s eta 0:00:00
# Downloading qdldl-0.1.7.post4-cp312-cp312-macosx_11_0_arm64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 12.9 MB/s eta 0:00:00
# Building wheels for collected packages: ecos
#   Building wheel for ecos (pyproject.toml) ... done
#   Created wheel for ecos: filename=ecos-2.0.14-cp312-cp312-macosx_11_0_arm64.whl size=72741 sha256=3eeebbd1a95bafd6a08b797448c6ee84ed389159a090c62e0d50643cf8b98f1e
#   Stored in directory: /Users/augustincablant/Library/Caches/pip/wheels/b8/d9/1e/77a592ed2465d4dde07f30f787f9d43834c0fd7a1467371694
# Successfully built ecos
# Installing collected packages: scs, qdldl, ecos, clarabel, osqp, cvxpy
# Successfully installed clarabel-0.9.0 cvxpy-1.5.3 ecos-2.0.14 osqp-0.6.7.post3 qdldl-0.1.7.post4 scs-3.2.7

# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

# %% [markdown]
# Optimal Transport of Discrete Distributions
# ------------------------------------------
#
# We consider two dicretes distributions
# $$ \al = \sum_{i=1}^n a_i \de_{x_i} \qandq
#    \be = \sum_{j=1}^m b_j \de_{y_j}. $$
#
# where $n,m$ are the number of points, $\de_x$ is the Dirac at
# location $x \in \RR^d$, and $(x_i)_i, (y_j)_j$ are the positions of the diracs in $\RR^d$.

# %% [markdown]
# Dimensions $(n,m)$ of the coulds.

# %%
n = 60
m = 80

# %% [markdown]
# Generate the point clouds $X=(x_i)_i$ and $Y=(y_j)_j$.

# %%
np.tile(2, (4, 1)), np.transpose(np.tile(2, (4, 1))), np.random.randn(2, 4)
# Out:
# (array([[2],
#         [2],
#         [2],
#         [2]]),
#  array([[2, 2, 2, 2]]),
#  array([[ 0.83558566, -0.35255337,  1.5826303 ,  1.13174571],
#         [-1.84608134,  0.06107462, -0.75703471, -0.7737623 ]]))

# %%
gauss = lambda q, a, c: a * np.random.randn(2, q) + np.transpose(np.tile(c, (q, 1)))    # a * [[N(0, 1), ..., N(0, 1)], \n [N(0, 1), ..., N(0, 1)]] + [[c, c, ..., c], \n [c, c, ..., c]] = (N(c, a^2 I_2))^q
X = np.random.randn(2, n) * .3
Y = np.hstack((gauss(int(m/2),.5,[0,1.6]), np.hstack((gauss(int(m/4),.3,[-1,-1]), gauss(int(m/4),.3,[1,-1])))))

# %%
Y.shape
# Out:
# (2, 80)

# %%
plt.figure(figsize=(8,6))
plt.hist(X[0, :], bins = 30, alpha = 0.5, label='X[0]', density = True)
plt.hist(X[1, :], bins = 30, alpha = 0.5, label='X[1]', density = True)
plt.vlines(np.mean(X[0, :]), 0, 3, color = 'r', linestyle = '--', label = 'mean of X[0]')
plt.hist(Y[0, :], bins = 30, alpha = 0.5, label='Y[0]', density = 'True')
plt.vlines(np.mean(Y[0, :]), 0, 3, color = 'black', linestyle = '--', label = 'mean of Y[0]')
plt.legend()
plt.show()

# %% [markdown]
# Generate the weights $a,b$.

# %%
normalize = lambda a: a/np.sum(a)
a = normalize(np.random.rand(n, 1))
b = normalize(np.random.rand(m, 1))

# %% [markdown]
# Helper function for display of clouds.

# %%
myplot = lambda x, y, ms, col: plt.scatter(x, y, s = ms * 20, edgecolors = "k", c = col, linewidths = 2)

# %% [markdown]
# Display the point clouds.
# The size of each dot is proportional to its probability density weight.

# %%
plt.figure(figsize = (10,7))
plt.axis("off")
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Compute the cost matrix $C_{i,j} := \norm{x_i-x_j}^2$.

# %%
def distmat(x,y):
    return np.sum(x**2,0)[:,None] + np.sum(y**2,0)[None,:] - 2*x.transpose().dot(y)
C = distmat(X,Y)

# %% [markdown]
# Define the optimiztion variable $P$.

# %%
P = cp.Variable((n,m))

# %% [markdown]
# Define the set of discrete couplings between $\al$ and $\be$
# $$ U(a,b) := \enscond{ P \in \RR_+^{n \times m} }{
#      \forall i, \sum_j P_{i,j} = a_i, \:
#      \forall j, \sum_i P_{i,j} = b_j }. $$

# %%
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]

# %% [markdown]
# The Kantorovitch formulation of the optimal transport reads
# $$ P^\star \in \uargmin{P \in U(a,b)} \sum_{i,j} P_{i,j} C_{i,j}.  $$
# Solve it using CVXPY

# %%
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve()

# %% [markdown]
# An optimal coupling $P^\star$ can be shown to be a sparse matrix
# with less than $n+m-1$ non zero entries. An entry $P_{i,j}^\star \neq 0$
# should be understood as a link between $x_{i}$
# and $y_{j}$ where an amount of mass equal to $P_{i,j}^\star$ is transfered.

# %% [markdown]
# Check that the number of non-zero entries in $P^\star$ is $n+m-1$. Beware that we are using an interior point method here, so that entries of $P^\star$ are nevery exactly 0.

# %%
print("Number of non-zero: %d (n + m-1 = %d)" %(len(P.value[P.value>1e-5]), n + m-1))
# Out:
# Number of non-zero: 138 (n + m-1 = 139)

# %% [markdown]
# Display the solution coupling.

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %% [markdown]
# Display the connexion defined by the optimal coupling.

# %%
I,J = np.nonzero(P.value>1e-5)
plt.figure(figsize = (10,7))
plt.axis('off')
for k in range(len(I)):
    h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Displacement Interpolation
# --------------------------
# For any $t \in [0,1]$, one can define a distribution $\mu_t$ such
# that $t \mapsto \mu_t$ defines a geodesic for the Wasserstein metric.
#
#
# Since the $W_2$ distance is a geodesic distance, this geodesic path solves the
# following variational problem
#
# $$ \mu_t = \uargmin{\mu} (1-t)W_2(\al,\mu)^2 + t W_2(\be,\mu)^2. $$
# This can be understood as a generalization of the usual Euclidean
# barycenter to barycenter of distribution. Indeed, in the case that
# $\al = \de_{x}$ and $\be=\de_y$, one has $\mu_t=\de_{x_t}$ where $ x_t =
# (1-t)x+t y $.
#
#
# Once the optimal coupling $P^\star$ has been computed, the
# interpolated distribution is obtained as
#
# $$ \mu_t = \sum_{i,j} P^\star_{i,j} \de_{(1-t)x_{i} + t y_{j}}. $$

# %% [markdown]
# Find the $i,j$ with non-zero $P_{i,j}^\star$.

# %%
I,J = np.nonzero(P.value>1e-5)
Pij = P.value[I,J]

# %% [markdown]
# Display the evolution of $\mu_t$ for a varying value of $t \in [0,1]$.

# %%
plt.figure(figsize =(15,10))
tlist = np.linspace(0, 1, 6)
for i in range(len(tlist)):
    t = tlist[i]
    Xt = (1-t)*X[:,I] + t*Y[:,J]
    plt.subplot(2,3,i+1)
    plt.axis("off")
    for j in range(len(Pij)):
        myplot(Xt[0,j],Xt[1,j],Pij[j]*len(Pij)*6,[[t,0,1-t]])
    plt.title("t = %.1f" %t) 
    plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
    plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Optimal Assignement
# -------------------
# In the case where $n=m$ and the weights are uniform $a_{i}=1/n, b_{j}=1/n$, one can show that there is at least one optimal transport coupling which is actually a
# permutation matrix. This properties comes from the fact that
# the extremal point of the polytope $U(1,1)$ are permutation matrices.
#
#
# This means that there exists an optimal permutation $\si^\star \in \Sigma_n$ such
# that
# $$ P^\star_{i,j} = \choice{
#       1 \qifq j=\si^\star(i), \\
#       0 \quad\text{otherwise}.
#   } $$
#
# where $\Si_n$ is the set of permutation (bijections) of
# $\{1,\ldots,n\}$.
#
#
# This permutation thus solves the so-called optimal assignement problem
# $$ \si^\star \in \uargmin{\si \in \Sigma_n}
#       \sum_{i} C_{i,\si(j)}. $$

# %% [markdown]
# Use the same number of points.

# %%
n = 40
m = n

# %% [markdown]
# Compute points clouds.

# %%
X = np.random.randn(2,n)*.3
Y = np.hstack((gauss(int(m/2),.5,[0,1.6]),np.hstack((gauss(int(m/4),.3,[-1,-1]),gauss(int(m/4),.3,[1,-1])))))

# %% [markdown]
# Constant distributions.

# %%
a = np.ones([n,1])/n
b = a

# %% [markdown]
# Compute the weight matrix $ (C_{i,j})_{i,j}. $

# %%
C = distmat(X,Y)

# %% [markdown]
# Display the coulds.

# %%
plt.figure(figsize = (10,7))
plt.axis('off')
myplot(X[0,:],X[1,:],10,'b')
myplot(Y[0,:],Y[1,:],10,'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Solve the optimal transport.

# %%
P = cp.Variable((n,m))
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve()

# %% [markdown]
# Show that $P$ is a binary permutation matrix.

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %% [markdown]
# Display the optimal assignement.

# %%
I,J = np.nonzero(P.value>1e-5)
plt.figure(figsize = (10,7))
plt.axis('off')
for k in range(len(I)):
    h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)
myplot(X[0,:], X[1,:], 10, 'b')
myplot(Y[0,:], Y[1,:], 10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [raw]
# <script>
#   $(document).ready(function(){
#       $('div.prompt').hide();
#   });
# </script>
